# %%
import scrapy
import os
import sys

# %%
# User specified file path, set as you wish
path0 = 'D:\College\College Courses\CS 429\Project\downFiles'
os.chdir(path0)
os.getcwd()
# Out:
# 'D:\\College\\College Courses\\CS 429\\Project\\downFiles'

# %%
# Begin Crawling
# !scrapy crawl Scrapy_Crawler
# Out:
# 2022-04-28 10:45:16 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: downFiles)
# 2022-04-28 10:45:16 [scrapy.utils.log] INFO: Versions: lxml 4.6.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.4.0, Python 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.1.1, Platform Windows-10-10.0.19041-SP0
# 2022-04-28 10:45:16 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'downFiles',
#  'DEPTH_LIMIT': '1',
#  'NEWSPIDER_MODULE': 'downFiles.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['downFiles.spiders']}
# 2022-04-28 10:45:16 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-04-28 10:45:16 [scrapy.extensions.telnet] INFO: Telnet Password: 29b01154ea6f2ea0
# 2022-04-28 10:45:16 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...

# %%
# After the crawling is finished. There should be a new folder called 'full' in the '.../Project' directory.
# This folder contains all the web pages crawled and downloaded as html

# %%
# Use this 'exit' command in case crawler does not stop

# exit
